# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
data_dir = '/Users/zcasparcohen/Documents/NISKINE/GDP_data/'

# %%
ds_gdp = xr.open_dataset(data_dir+'gdp_combined.nc')
ds_gdp = ds_gdp.rename({'lon':'lon_bin','lat':'lat_bin'})

# %%
ds_gdp.sel(lat_bin=slice(56,64),lon_bin=slice(-24,-18)).dcount.plot(y='lat_bin')
